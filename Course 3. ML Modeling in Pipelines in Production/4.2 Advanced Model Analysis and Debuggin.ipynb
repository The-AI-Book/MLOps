# %% [markdown]
# # Week 4. Advanced Model Analysis and Debugging
# ---
#
# <img src = "https://i.gyazo.com/abfe654cd80fc23994493694d5671de2.png">
#
# <img src = "https://i.gyazo.com/1ce4f18c088f3d158ab21d25e7286475.png">
#
# <img src = "https://i.gyazo.com/8b458bb0695d6868549132fd91e9f33a.png">
#
# - TensorBoard and TFMA are used in different stages of the development process.
# - At a high level, TensorBoard is used to analyze the training process itself while TFMA a is used to do deep analysis of the finished trained model.
#
# <img src = "https://i.gyazo.com/749597b335170a0a6f2771ceac158ac9.png">
#
# - While, TensorBoard visualizes streaming metrics of multiple models over global training sets
# - TFMA visualizes the metrics computed for a single model over multiple versions of the exported saved model.
#
# <img src = "https://i.gyazo.com/ab0497d4b720346b9ccad756f74c6a8c.png">
#
# <img src = "https://i.gyazo.com/dc327d90197a932bdcd73fba5b338779.png">

# %% [markdown]
# ## TFMA in Practice
# ---
#
# - Analyse impact of different slices of data over various metrics
# - How to track metrics over time?

# %% [markdown]
# ## Model Debugging
# ---
#
# ### Model robutness
# ---
# - Robustness is much more than generalization
# - Is the model accurate even for slightly corrupted input data?
#
# ### Model debugging
# - Deals with detecting and dealing with problems in ML systems
# - Applies mainstream software engineering practices to ML models
# - Model debugging attempts to test ML models just like code, very similar to how you attest in software development. It probes sophisticated ML response functions and decision boundaries to detect and correct accuracy, fairness, security, and other problems in ML systems.
# - Model debugging tries to improve the transparency of models by highlighting how data is flowing inside.
# - Model debugging also aims to reduce the vulnerability of your model to attacks.
#
# <img src = "https://i.gyazo.com/d7308f2426f57e6b7573ddddd5dd8249.png" width = "500px">
#
# ### Benchmark models
# ---
# <img src = "https://i.gyazo.com/c95679517aaa73b9e0dfd1cc2f5fe030.png" width = "500px">
#
#
# ### Sensitivity Analysis and Adversarial Attacks
# ---
# - What-If Tool for sensitivity analysis
# - Random attack
# - Partial dependence plots (PDPbox)
#
# ### How vulnerable to attacks is your model?
# Sensitivity can mean vulnerability
# - Attacks are aimed at fooling your model
# - Successful attacks could be catastrophic
# - Test adversarial examples
# - Harden your model
#
#
# ### Informational Harms
# <img src = "https://i.gyazo.com/37f60ba8b911e0126f7b9cab68b578ec.png" width = "500px">
#
# ### Behavioral Harms
# <img src = "https://i.gyazo.com/a48d27106494d1aecabc97530031c5f0.png" width = "500px">
#
# ### Measuring your vulnerability to attack
# - Cleverhans Python Library: an open-source Python library to benchmark machine learning systems' vulnerability to adversarial examples
# - Adversarial training
# - Foolbox: Lets you easily run adversarial attacks against machine learning models.
#
# ### Defensive Destillation
#
# ### Residual analysis
# - Measures the difference between model's predictions and ground truth
# - Randonmly distributed errors are good
# - Correlated or systematic errors show that a model can be improved
#
# ## Remediation techniques
# ---
#
# - Data augmentation
# - Adding synthetic data intro training set
# - Helps correct for unbalanced training data
# - Model editing: Applies to decision trees, Manual tweaks to adapt your use case
# - Model assertions: Implement business rules that override model predictions
#
# <img src = "https://i.gyazo.com/a7ad53aa064239dac06236c907fcc65b.png" width = "500px">
#
# ### Fainess indicators library
